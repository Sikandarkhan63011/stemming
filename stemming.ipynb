ھولو', 'پہلوان', 'صاحبزادے', 'ناصر', 'بھولو', 'بتائی', 'تاہم', 'خاندان', 'ماضی', 'انتہائی', 'درخشاں'], ['قومی', 'ٹوئنٹی', 'اوپنرز', 'امام', 'الحق', 'فخرزمان', 'منظور', 'مسعود', 'شرجیل', 'قابل', 'اننگز', 'دیکھنے', 'اندازہ', 'لگانا', 'مشکل', 'پاکستانی', 'ٹوئنٹی', 'بنانے', 'اوپنرز', 'کتنا', 'مقابلہ']]
        
        }

df = pd.DataFrame(cars, columns = ['Root'])

df.to_excel (r'C:\Users\sikandar khan\Desktop\dataurdu.xlsx', index = False, header=True)
print(df)
# Out:
#                                                  Root
# 0   [پروفیسر, منظور, احمد, گذشتہ, لاہور, انتقال, ا...
# 1   [نواز, شریف, لندن, بذریعہ, ویڈیو, خطاب, دوران,...
# 2   [صوبہ, بلوچستان, خیبرپختونخوا, سکیورٹی, فورسز,...
# 3   [پاکستان, صوبہ, خیبر, پختونخوا, قبائلی, علاقے,...
# 4   [انڈیا, اختلاف, جماعت, کانگریس, رہنما, راہل, گ...
# 5   [جمعرات, ہدایت, نامہ, جاری, مطابق, متحدہ, امار...
# 6   [کراچی, وفاقی, تحقیقاتی, ادارے, خاتون, سابقہ, ...
# 7   [گوجرانوالہ, کالج, باہر, متعدد, مشہور, شخصیات,...
# 8   [1940, دہائی, دوستوں, جوتوں, کاروبار, شروع, وس...
# 9   [اداکارہ, چکرورتی, والدہ, سندھیا, کہنا, نیند, ...
# 10  [بالی, پروڈیوسرز, ایسوسی, ایشنز, مشترکہ, انڈین...
# 11  [ایران, معروف, کلاسیکل, گلوکار, موجودہ, حکومت,...
# 12  [مرزا, سیریز, معروف, کردار, پنڈت, دیکھنے, جانب...
# 13  [پنجاب, دراز, دیہات, بھٹے, اینٹیں, بنانے, مزدو...
# 14  [زیورات, مقبول, برانڈ, تنشک, اشتہار, تنازع, ما...
# 15  [جسٹس, سارنگ, کوتوالی, بینچ, چکرورتی, دیگر, مل...
# ...

# %%
stem = ['چابیاں', 'ہڈیاں', 'لڑکیاں', 'کلہاڑیاں', 'شیشے', 'مکھیاں', 'ہاتھوں', 'لومڑیاں', 'آغائے', 'گھوڑے', 'کرسیاں', 'قینچیاں', 'بچے', 'بچھڑے', 'سیاسی', 'نظریے', 'حامی', 'بھیڑیں', 'دلچسپی', 'انھوں', 'قینچیاں', 'فوجیں', 'دکانیں', 'آسمانوں','ڈاکٹروں']
print(stem)
print("\n_________________________________")
print("stemm")
print("_________________________________\n")
b = []
c = []
for x in stem: 
    y = x[-2:]
    if y == 'اں':
        x = x[:-2]
        #x = x +'ی' 
        print(x) 
    elif y == 'یں':
       x = x[:-2]
       #x = x+'ا'  
       print(x)     
    elif y == 'ی':
       x = x[:-1]
       #x = x+'ا'  
       print(x) 
    elif y == 'وں':
       x = x[:-2]
       #x = x+'ا'  
       print(x)   
    b.append(x)
print('\n---\n') 
for j in b: 
    k = j[-1:]     
    if k == 'ے':
       j = j[:-1]
       j = j+'ا' 
       print(j)
    c.append(j)
print('\n')      
print(c) 
print(c[2:5])
# Out:
# ['چابیاں', 'ہڈیاں', 'لڑکیاں', 'کلہاڑیاں', 'شیشے', 'مکھیاں', 'ہاتھوں', 'لومڑیاں', 'آغائے', 'گھوڑے', 'کرسیاں', 'قینچیاں', 'بچے', 'بچھڑے', 'سیاسی', 'نظریے', 'حامی', 'بھیڑیں', 'دلچسپی', 'انھوں', 'قینچیاں', 'فوجیں', 'دکانیں', 'آسمانوں', 'ڈاکٹروں']
#
# _________________________________
# stemm
# _________________________________
#
# چابی
# ہڈی
# لڑکی
# کلہاڑی
# مکھی
# ہاتھ
# لومڑی
# کرسی
# قینچی
# بھیڑ
# انھ
# قینچی
# فوج
# دکان
# آسمان
# ڈاکٹر
#
# ---
#
# شیشا
# آغائا
# گھوڑا
# بچا
# بچھڑا
# نظریا
#
#
# ['چابی', 'ہڈی', 'لڑکی', 'کلہاڑی', 'شیشا', 'مکھی', 'ہاتھ', 'لومڑی', 'آغائا', 'گھوڑا', 'کرسی', 'قینچی', 'بچا', 'بچھڑا', 'سیاسی', 'نظریا', 'حامی', 'بھیڑ', 'دلچسپی', 'انھ', 'قینچی', 'فوج', 'دکان', 'آسمان', 'ڈاکٹر']
# ['لڑکی', 'کلہاڑی', 'شیشا']

# %%
Prefix = ['ناپاک', 'ناخواندگی', 'نامکمل', 'ناخوش', 'ناکام', 'ناخوش', 'خوش قسمت', 'خوش ذائقہ', 'خوش گوار', 'بے مثال', 'بے شرم', 'بے رحم']
print("________Prefix_________")
print("_______________________")
print("\n")
print("نا |Prefix")
for suf in Prefix:
   fir = suf[0:2]
   if fir == 'نا':
      suf = suf[2:] 
      print(suf)

print("_______________________")
print("\n")
print("خوش |Prefix")   
for suf2 in Prefix:
   fir2 = suf2[0:3]
   if fir2 == 'خوش':
      suf2 = suf2[3:] 
      print(suf2)

print("_______________________")
print("\n")
print("بے |Prefix")   
for suf3 in Prefix:
   fir3 = suf3[0:2]
   if fir3 == 'بے':
      suf3 = suf3[2:] 
      print(suf3)
# Out:
# ________Prefix_________
# _______________________
#
#
# نا |Prefix
# پاک
# خواندگی
# مکمل
# خوش
# کام
# خوش
# _______________________
#
#
# خوش |Prefix
#  قسمت
#  ذائقہ
#  گوار
# _______________________
#
#
# بے |Prefix
#  مثال
#  شرم
#  رحم

# %%
suffix = ['زمیندار', 'بدبودار', 'خوشبودار', 'ترسناک', 'خوفناک', 'عبرتناک', 'خطرناک', 'جوابات', 'تقریبات', 'تقریبات', 'رشتہ دار']
print("________suffix_________")
print("_______________________")
print("\n")
print(" ات  |suffix")  
for pre in suffix:
   las = pre[-2:]
   if las == 'ات':
      pre = pre[:-2] 
      print(pre)
print("_______________________")
print("\n")
print("ناک |suffix")       
for pre in suffix:
   las = pre[-3:]
   if las == 'ناک':
      pre = pre[:-3] 
      print(pre)  
      
print("_______________________")
print("\n")
print("دار |suffix")       
for pre in suffix:
   las = pre[-3:]
   if las == 'دار':
      pre = pre[:-3] 
      print(pre)
# Out:
# ________suffix_________
# _______________________
#
#
#  ات  |suffix
# جواب
# تقریب
# تقریب
# _______________________
#
#
# ناک |suffix
# ترس
# خوف
# عبرت
# خطر
# _______________________
#
#
# دار |suffix
# زمین
# بدبو
# خوشبو
# رشتہ
